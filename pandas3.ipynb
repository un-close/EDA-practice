# %%
import pandas as pd
df = pd.read_csv('train-data.csv', index_col = 0)
df.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    New_Price  Price
# 0        NaN   1.75
# 1        NaN  12.50
# ...

# %%
df.shape
# Out:
# (6019, 13)

# %%
df.Fuel_Type.unique()
# Out:
# array(['CNG', 'Diesel', 'Petrol', 'LPG', 'Electric'], dtype=object)

# %%
df.isnull().sum()
# Out:
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 36
# Power                  36
# Seats                  42
# New_Price            5195
# Price                   0
# dtype: int64

# %%
# data preprocessing and remove any irregularities in the data
# create ml mode to make predictions about resale value of cars
df1 = df.drop('New_Price', axis='columns')
df1.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    Price
# 0   1.75
# 1  12.50
# 2   4.50
# 3   6.00
# 4  17.74

# %%
k = '18.2 kmpl'
float(k.split(' ')[0])
# Out:
# 18.2

# %%
def fix_units(x):
    try:
        return float(x.split(' ')[0])
    except:
        return x
    
df1['Mileage'] = df['Mileage'].apply(fix_units)

# %%
df1['Engine'] = df1['Engine'].apply(fix_units)
df1['Power'] = df1['Power'].apply(fix_units)
df1['Power']
# Out:
# 0       58.16
# 1       126.2
# 2        88.7
# 3       88.76
# 4       140.8
#         ...
# 6014     74.0
# 6015     71.0
# 6016    112.0
# 6017     67.1
# 6018     57.6
# Name: Power, Length: 6019, dtype: object

# %%
df1[df1['Power'].apply(lambda x:type(x) != float)]
# Out:
#                                       Name   Location  Year  \
# 76                Ford Fiesta 1.4 SXi TDCi     Jaipur  2008
# 79                  Hyundai Santro Xing XL  Hyderabad  2005
# 89                  Hyundai Santro Xing XO  Hyderabad  2007
# 120   Hyundai Santro Xing XL eRLX Euro III     Mumbai  2005
# 143    Hyundai Santro Xing XO eRLX Euro II      Kochi  2008
# ...                                    ...        ...   ...
# 5873   Hyundai Santro Xing XO eRLX Euro II       Pune  2006
# 5893                     Maruti Estilo LXI    Chennai  2008
# 5925           Skoda Laura Classic 1.8 TSI       Pune  2010
# 5943               Mahindra Jeep MM 540 DP    Chennai  2002
# 5985                       Toyota Etios GD      Delhi  2013
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# 76               111111    Diesel       Manual      First    17.80  1399.0
# 79                87591    Petrol       Manual      First     0.00  1086.0
# ...

# %%
import numpy as np
df1['Power'].apply(lambda x : x if type(x) == float else np.nan)
# Out:
# 0        58.16
# 1       126.20
# 2        88.70
# 3        88.76
# 4       140.80
#          ...
# 6014     74.00
# 6015     71.00
# 6016    112.00
# 6017     67.10
# 6018     57.60
# Name: Power, Length: 6019, dtype: float64

# %%
df1['Power'] = df1['Power'].apply(lambda x : x if type(x) == float else np.nan)
df1.isnull().sum()
# Out:
# Name                   0
# Location               0
# Year                   0
# Kilometers_Driven      0
# Fuel_Type              0
# Transmission           0
# Owner_Type             0
# Mileage                2
# Engine                36
# Power                143
# Seats                 42
# Price                  0
# dtype: int64

# %%
df1['Fuel_Type'].value_counts()
# Out:
# Fuel_Type
# Diesel      3205
# Petrol      2746
# CNG           56
# LPG           10
# Electric       2
# Name: count, dtype: int64

# %%
df1[df1['Fuel_Type'].isin(['Diesel', 'Petrol'])]
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# 6               Nissan Micra Diesel XV      Jaipur  2013              86999
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
# ...

# %%
df1['Transmission'].value_counts()
# Out:
# Transmission
# Manual       4299
# Automatic    1720
# Name: count, dtype: int64

# %%
df1['Owner_Type'].value_counts()
# Out:
# Owner_Type
# First             4929
# Second             968
# Third              113
# Fourth & Above       9
# Name: count, dtype: int64

# %%
df1['Owner_Type'] =  df1['Owner_Type'].apply(lambda x : 'First' if x == 'First' else 'Second and above')

# %%
df1.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission        Owner_Type  Mileage  Engine   Power  Seats  \
# 0       CNG       Manual             First    26.60   998.0   58.16    5.0
# 1    Diesel       Manual             First    19.67  1582.0  126.20    5.0
# 2    Petrol       Manual             First    18.20  1199.0   88.70    5.0
# 3    Diesel       Manual             First    20.77  1248.0   88.76    7.0
# 4    Diesel    Automatic  Second and above    15.20  1968.0  140.80    5.0
#
#    Price
# 0   1.75
# 1  12.50
# 2   4.50
# 3   6.00
# 4  17.74
